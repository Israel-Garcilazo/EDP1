# %% [markdown]
# <a href="https://colab.research.google.com/github/Israel-Garcilazo/EDP1/blob/main/Actividad3V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A cotinuaciòn el proceso necesario para imnprimir la serie de Fourier asociada a $$ f(x) = exp(2x) $$
# En funciòn de cosenos.

# %%
from sympy import fourier_series, pi, plot, Piecewise, exp
from sympy.abc import x
import numpy as np

# %%
f1= exp(2*x)
plot(f1, (x,-2,2),line_color ='blue')

# %%
s = fourier_series(f1, (x, 0, 1))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p1 = plot(f1, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
p1[0].label = 'x'
p1[1].label = 'n=3'
p1[2].label = 'n=5'
p1[3].label = 'n=7'

# %%
p1.show()

# %% [markdown]
# Ahora hacemos lo mismo para la serie de Fourier en funciòn de cosenos.

# %%
f2= exp(2*x)
plot(f2, (x,-2,2),line_color ='orange')

# %%
s = fourier_series(f1, (x, -1, 1))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p2 = plot(f2, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
p2[0].label = 'x'
p2[1].label = 'n=3'
p2[2].label = 'n=5'
p2[3].label = 'n=7'

# %%
p2.show()

# %% [markdown]
# Ahora hacemos lo mismo para la funcion a trozos dada:

# %%
f3= Piecewise(
    (1, (0 <= x) & (x <= pi/2)),
    (2, (pi/2 < x) & (x <= pi)))

# %%
plot(f3, (x,-2*pi,2*pi),line_color ='red')

# %%
s = fourier_series(f, (x, -2*pi, 2*pi))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()
